# %% [markdown]
# # SPW_2.04
# - **Description** : Visualization of Probability Distributions
# - **Source** : The Statistics and Calculus with Python Workshop - Farrell, Fuentes, Kolhe
# - **Chapter** :  2 - Python's Main Tools for Statistics
# - **Exercise** : 2.04

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
samples = np.random.normal(0, 1, size=1000)

# %%
x = np.linspace(samples.min(), samples.max(), 1000)
y = stats.norm.pdf(x)

# %%
plt.hist(samples, alpha=0.2, bins=20, density=True)
plt.plot(x, y)
plt.show()

# %%
samples = np.random.beta(2, 5, 1000)
x = np.linspace(samples.min(), samples.max(), 1000)
y = stats.beta.pdf(x, 2, 5)

plt.hist(samples, alpha=0.2, bins=20, density=True)
plt.plot(x, y)
plt.show()

# %%
samples = np.random.gamma(1, size=1000)
x = np.linspace(samples.min(), samples.max(), 1000)
y = stats.gamma.pdf(x, 1)
plt.hist(samples, alpha=0.2, bins=20, density=True)
plt.plot(x, y)
plt.show()
